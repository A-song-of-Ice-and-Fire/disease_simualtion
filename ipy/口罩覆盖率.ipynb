# %%
import pandas as pd
import matplotlib.pyplot as plt
import pylab as mpl

# %%
mpl.rcParams["font.sans-serif"] = ["FangSong"]
mpl.rcParams["axes.unicode_minus"] = False

# %%
df1 = pd.read_csv(r"E:\news_data\口罩防护\5040_0_20210921205024.csv")
df2 = pd.read_csv(r"E:\news_data\口罩防护\5040_04_20210922132433.csv")
df3 = pd.read_csv(r"E:\news_data\口罩防护\5040_08_20210922222320.csv")
df4 = pd.read_csv(r"E:\news_data\口罩防护\5040_10_20210923002447.csv")

# %%
plt.figure(figsize=(15,12))
plt.plot(df1["i_ratio"],label = "口罩覆盖率=0",color="#CE466A",linewidth=3)
plt.plot(df2["i_ratio"],label = "口罩覆盖率=0.4",color="#589BAD",linewidth=3)
plt.plot(df3["i_ratio"],label = "口罩覆盖率=0.8",color="#FAA055",linewidth=3)
plt.xlabel(xlabel = "时间步",fontsize=30)
plt.ylabel(ylabel="感染者比例",fontsize=30)
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
plt.legend(fontsize=20)
